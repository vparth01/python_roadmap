# %%
# arithmetic operators 

a=10 
b =3 

a/b #(division)
a%b #(modulus) or remainder
a**b #(exponent)
# Out:
# 1000

# %%
# operator behaviours with different data types

a = 10
b = 20

print(a + b)

str1 = "hello"
str2 = "world"

print(str1 + " " + str2 )

print(str1 * 3)
# Out:
# 30
# hello world
# hellohellohello

# %%
# while loop example
count = 0

while count < 5:
    print("count:", count)
    count +=1
# Out:
# count: 0
# count: 1
# count: 2
# count: 3
# count: 4
